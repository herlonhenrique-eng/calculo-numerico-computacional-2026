# %%
import numpy as np
import matplotlib.pyplot as plt

# Definindo a função
def f(x):
    return x**3 - x - 2

# Criando valores de x no intervalo [1, 2]
x = np.linspace(1, 2, 100)
y = f(x)

# Plotando o gráfico
plt.figure()
plt.plot(x, y)
plt.axhline(0)  # eixo x
plt.axvline(0)  # eixo y
plt.title('Gráfico de f(x) = x³ - x - 2')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()

plt.show()

# %% [markdown]
# Observação do gráfico – Ao analisar o gráfico, percebe-se que a raiz está localizada aproximadamente em x ≈ 0,74, ponto em que a função intercepta o eixo horizontal (y = 0).
#
# Quantidade de raízes no intervalo – Dentro do intervalo considerado, a função apresenta somente uma raiz, não sendo identificados outros pontos de interseção com o eixo x.

# %%
import pandas as pd

# Definindo a função
def f(x):
    return x**3 - x - 2

# Intervalo inicial
a = 1
b = 2

# Número de iterações
n = 10

# Lista para armazenar os dados
dados = []

for i in range(1, n + 1):
    c = (a + b) / 2
    fc = f(c)

    # Guardando os valores
    dados.append([i, a, b, c, fc])

    # Método da bissecção
    if f(a) * fc < 0:
        b = c
    else:
        a = c

# Criando tabela
tabela = pd.DataFrame(dados, columns=["Iteração", "a", "b", "c", "f(c)"])

# Exibindo
print(tabela)
# Out:
#    Iteração         a         b         c      f(c)
# 0         1  1.000000  2.000000  1.500000 -0.125000
# 1         2  1.500000  2.000000  1.750000  1.609375
# 2         3  1.500000  1.750000  1.625000  0.666016
# 3         4  1.500000  1.625000  1.562500  0.252197
# 4         5  1.500000  1.562500  1.531250  0.059113
# 5         6  1.500000  1.531250  1.515625 -0.034054
# 6         7  1.515625  1.531250  1.523438  0.012250
# 7         8  1.515625  1.523438  1.519531 -0.010971
# 8         9  1.519531  1.523438  1.521484  0.000622
# 9        10  1.519531  1.521484  1.520508 -0.005179

# %%
import pandas as pd

# Função
def f(x):
    return x**3 - x - 2

# Derivada
def df(x):
    return 3*x**2 - 1

# Valor inicial (próximo da raiz da bissecção)
x = 1.52

# Número de iterações
n = 10

# Lista para armazenar resultados
dados = []

for i in range(1, n + 1):
    fx = f(x)
    dfx = df(x)

    # Método de Newton
    x_new = x - fx / dfx

    # Erro absoluto
    erro = abs(x_new - x)

    # Armazenar dados
    dados.append([i, x, fx, erro])

    # Atualizar x
    x = x_new

# Criar tabela
tabela = pd.DataFrame(dados, columns=["Iteração", "x_n", "f(x_n)", "erro"])

# Exibir tabela
tabela
# Out:
#    Iteração       x_n        f(x_n)          erro
# 0         1  1.520000 -8.192000e-03  1.381171e-03
# 1         2  1.521381  8.701440e-06  1.463952e-06
# 2         3  1.521380  9.781065e-12  1.645573e-12
# 3         4  1.521380  0.000000e+00  0.000000e+00
# 4         5  1.521380  0.000000e+00  0.000000e+00
# 5         6  1.521380  0.000000e+00  0.000000e+00
# 6         7  1.521380  0.000000e+00  0.000000e+00
# 7         8  1.521380  0.000000e+00  0.000000e+00
# 8         9  1.521380  0.000000e+00  0.000000e+00
# 9        10  1.521380  0.000000e+00  0.000000e+00

# %%
import pandas as pd

# Função e derivada
def f(x):
    return x**3 - x - 2

def df(x):
    return 3*x**2 - 1

# -------------------------
# MÉTODO DA BISSECÇÃO
# -------------------------
a = 1
b = 2
tol = 1e-6
max_iter = 100

iter_bis = 0

while (b - a)/2 > tol:
    c = (a + b)/2
    if f(a)*f(c) < 0:
        b = c
    else:
        a = c
    iter_bis += 1

raiz_bis = (a + b)/2
erro_bis = abs(f(raiz_bis))

# -------------------------
# MÉTODO DE NEWTON
# -------------------------
x = 1.52  # chute inicial
iter_newton = 0

for i in range(max_iter):
    x_new = x - f(x)/df(x)

    if abs(x_new - x) < tol:
        break

    x = x_new
    iter_newton += 1

raiz_newton = x
erro_newton = abs(f(x))

# -------------------------
# COMPARAÇÃO
# -------------------------
comparacao = pd.DataFrame({
    "Método": ["Bissecção", "Newton"],
    "Raiz aproximada": [raiz_bis, raiz_newton],
    "Iterações": [iter_bis, iter_newton],
    "Erro final": [erro_bis, erro_newton]
})

comparacao
# Out:
#       Método  Raiz aproximada  Iterações    Erro final
# 0  Bissecção          1.52138         19  4.265829e-06
# 1     Newton          1.52138          2  9.781065e-12

# %%
import pandas as pd

# Função e derivada
def f(x):
    return x**3 - x - 2

def df(x):
    return 3*x**2 - 1

# Lista de chutes iniciais
chutes = [1, 2, 20]

# Parâmetros
tol = 1e-6
max_iter = 50

# Lista para resultados
resultados = []

for x0 in chutes:
    x = x0
    iteracoes = 0

    for i in range(max_iter):
        # Evitar divisão por zero
        if df(x) == 0:
            break

        x_new = x - f(x)/df(x)

        if abs(x_new - x) < tol:
            x = x_new
            break

        x = x_new
        iteracoes += 1

    erro = abs(f(x))

    resultados.append([x0, x, iteracoes, erro])

# Criar tabela
tabela = pd.DataFrame(resultados, columns=[
    "Chute inicial (x0)", "Raiz aproximada", "Iterações", "Erro final"
])

# Exibir
tabela
# Out:
#    Chute inicial (x0)  Raiz aproximada  Iterações  Erro final
# 0                   1          1.52138          5         0.0
# 1                   2          1.52138          4         0.0
# 2                  20          1.52138         10         0.0

# %% [markdown]
# Experimento adicional – O método de Newton não assegura convergência em todas as situações; seu funcionamento pode falhar conforme a função analisada e a escolha do valor inicial.
#
# Impacto do valor inicial – A eficiência do método está fortemente ligada ao ponto de partida. Quando esse valor está próximo da raiz, a solução costuma ser encontrada rapidamente; caso contrário, o processo pode ser mais lento ou até não convergir.
#
# Análise da rapidez – Em geral, o método de Newton alcança a raiz com mais agilidade, pois utiliza a derivada para refinar as aproximações, enquanto o método da bissecção apenas divide o intervalo ao meio a cada iteração.
#
# Vantagens da bissecção – Esse método se destaca quando é necessário garantir a existência de uma raiz em determinado intervalo ou quando não se dispõe da derivada da função, já que ele não depende desse recurso.
#
# Aplicação em engenharia – Na prática, é comum empregar uma combinação dos dois métodos: inicialmente utiliza-se a bissecção para encontrar um intervalo adequado e, depois, aplica-se o método de Newton para obter a solução de forma mais rápida e precisa.
